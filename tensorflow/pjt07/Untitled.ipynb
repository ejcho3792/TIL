# %%
import pandas as pd

# %%
data=pd.read_excel('shampoo_naver_10page.xlsx')
data
# Out:
#                                 title  \
# 0       로더베르 시그니처 퍼퓸 샴푸 베이비파우더 1000ml
# 1        제이숲 딥그린제이 아로마 샴푸 일랑일랑 1000ml
# 2                모다모다 프로체인지 블랙샴푸 300g
# 3                 에스큐제약 모나다 샴푸 1000ml
# 4      아모스 녹차실감 산뜻한 타입 지성 모발용 샴푸 500g
# ..                                ...
# 361     엘라스틴 마스터 블렌드 미셀라 클렌징 샴푸 770ml
# 362  팬틴 PRO-V 헤어스파 실키 스무드 케어 샴푸 500ml
# 363                   딥 폴리큐어 샴푸 500ml
# 364               파놀라 노옐로우 보색샴푸 350ml
# 365        르네휘테르 아스테라 프레시 수딩 샴푸 200ml
#
#                                              spec_list    price  rate opinion
# 0    ['타입 : 일반샴푸', '형태 : 펌프형', '용량 : 1000ml(g)', '주...   9,900원   4.8   7,980
# 1    ['헤어타입 : 지성', '건성', '민감성', '모든 모발용', '타입 : 일반샴...  14,900원   4.7   3,307
# 2    ['헤어타입 : 모든 모발용', '타입 : 탈모샴푸', '형태 : 펌프형', '용량...  25,650원   4.6  15,302
# 3    ['헤어타입 : 모든 모발용', '타입 : 일반샴푸', '형태 : 펌프형', '용량...  52,300원   4.8   1,234
# 4    ['타입 : 두피샴푸', '형태 : 펌프형', '용량 : 500ml(g)', '주요...  13,830원   4.8  12,955
# ...

# %%
s=str(data['spec_list'][0])
ss=list(s.strip('["]'))
# Out:
# ["'",
#  '타',
#  '입',
#  ' ',
#  ':',
#  ' ',
#  '일',
#  '반',
#  '샴',
#  '푸',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '형',
#  '태',
#  ' ',
#  ':',
#  ' ',
#  '펌',
#  '프',
#  '형',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '용',
#  '량',
#  ' ',
#  ':',
#  ' ',
#  '1',
#  '0',
#  '0',
#  '0',
#  'm',
#  'l',
#  '(',
#  'g',
#  ')',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '주',
#  '요',
#  '제',
#  '품',
#  '특',
#  '징',
#  ' ',
#  ':',
#  ' ',
#  '세',
#  '정',
#  '력',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '풍',
#  '부',
#  '한',
#  ' ',
#  '거',
#  '품',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '세',
#  '부',
#  '제',
#  '품',
#  '특',
#  '징',
#  ' ',
#  ':',
#  ' ',
#  '향',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '저',
#  '자',
#  '극',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '약',
#  '산',
#  '성',
#  "'",
#  ',',
#  ' ',
#  "'",
#  '모',
#  '발',
#  '영',
#  '양',
#  "'"]

# %%
for i in range(len(data)):
