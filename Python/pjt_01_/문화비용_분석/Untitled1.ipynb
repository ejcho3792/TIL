# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('문화비용_자치구.csv')
d.to_excel('문화비용_자치구.xlsx',index=False)

# %%
d=pd.read_excel('문화비용_자치구.xlsx')
d=d.set_index('분류',drop=False)
d
# Out:
#        기간   분류  전시회 관람  박물관 관람  음악 및 무용발표회 관람  전통예술공연 관람  연극공연 관람  극장에서 영화관람  \
# 분류
# 서울시  2018  서울시   38997   14855          89475      25773    79302      47844
# 종로구  2018  종로구   22295    7566          87267      12431    68518      34957
# 중구   2018   중구    7273    6721          40385      12972    40698      42076
# 용산구  2018  용산구   19001   10033          65727       7990    50609      44204
# 성동구  2018  성동구   14741    6571          56184      11807    69991      39990
# ..    ...  ...     ...     ...            ...        ...      ...        ...
# 관악구  2020  관악구   18604   14519          68178      28399   102752      44671
# 서초구  2020  서초구   31734   22839         115779      52045    72197      47980
# 강남구  2020  강남구   44600   35421         134696      49326   126038      60122
# 송파구  2020  송파구   33480   15949          82020      27386   121255      53230
# 강동구  2020  강동구   27571   21087          76906      25421    92207      42922
#
#      대중공연 관람  스포츠경기 관람
# 분류
# ...

# %%
dd=pd.read_excel('analysis_data_culture.xlsx')
dd=dd.set_index('연도')
dd
# Out:
#       국민행복지수
# 연도
# 2018  136.11
# 2019  127.39
# 2020   81.01

# %%
gu=d['분류'].unique()
gu
# Out:
# array(['서울시', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype=object)

# %%
aa=[]
for i in gu:

    data=pd.DataFrame()
    data=d.loc[i]
    data=data.iloc[:,2:]
    data['국민행복지수']=np.array(dd['국민행복지수'])
    for j in data.columns:
        aa.append(data['국민행복지수'].corr(data[j]))

# %%
co=pd.DataFrame(np.reshape(aa,(26,9)))
co.columns=['전시회 관람', '박물관 관람', '음악 및 무용발표회 관람', '전통예술공연 관람', '연극공연 관람',
       '극장에서 영화관람', '대중공연 관람', '스포츠경기 관람','국민행복지수']
co.index=d.index[:26]
co
# Out:
#         전시회 관람    박물관 관람  음악 및 무용발표회 관람  전통예술공연 관람   연극공연 관람  극장에서 영화관람  \
# 분류
# 서울시   0.326714 -0.916380      -0.668245  -0.645279 -0.996279  -0.925256
# 종로구  -0.796179 -0.999427      -0.660739  -0.917635 -0.777181  -0.999038
# 중구   -0.651165 -0.275791      -0.999569  -0.985781 -0.999931  -0.665643
# 용산구  -0.835879 -0.988102      -0.959090  -0.996967 -0.999880  -0.945903
# 성동구  -0.906496 -0.876618      -0.967455  -0.820800 -0.844723  -0.728161
# 광진구   0.992002  0.161786       0.322131   0.972637 -0.069187   0.315198
# 동대문구  0.888026 -0.328017       0.989707  -0.733098 -0.383182   0.532370
# 중랑구  -0.830154 -0.671992      -0.587662  -0.367080 -0.724600  -0.380393
# 성북구   0.405446 -0.908092      -0.907175  -0.992899 -0.918454  -0.986135
# 강북구   0.436007 -0.762361      -0.055638  -0.970496 -0.165821  -0.275538
# 도봉구   0.929240  0.013251      -0.994101   0.561058 -0.943155   0.023534
# 노원구  -0.727494  0.212066       0.306891  -0.153728  0.300407   0.289311
# ...
