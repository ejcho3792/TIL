# %% [markdown]
# # Data visualization

# %% [markdown]
# ---
# 1. Anscombe dataset visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
anscombe=sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
data1=anscombe[anscombe['dataset']=='I']
data2=anscombe[anscombe['dataset']=='II']
data3=anscombe[anscombe['dataset']=='III']
data4=anscombe[anscombe['dataset']=='IV']

fig=plt.figure()

ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

ax1.set_title('data1')
ax2.set_title('data2')
ax3.set_title('data3')
ax4.set_title('data4')

ax1.plot(data1['x'],data1['y'],'o')
ax2.plot(data2['x'],data2['y'],'o')
ax3.plot(data3['x'],data3['y'],'o')
ax4.plot(data4['x'],data4['y'],'o')

fig.suptitle('anscombe data')
fig.tight_layout( )

# %% [markdown]
# ---
# 2. Matplotlib library - tips dataset

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=plt.figure()
ax1=fig.add_subplot(1,1,1)
ax1.hist(tips['total_bill'],bins=10)
ax1.set_title('histogram of total bill')
ax1.set_xlabel('frequency')
ax1.set_ylabel('total_bill')
# Out:
# Text(0, 0.5, 'total_bill')

# %%
scatters=plt.figure()
ax1=scatters.add_subplot(1,1,1)
ax1.scatter(tips['total_bill'],tips['tip'])
ax1.set_title('scatterplot of total bill vs tip')
ax1.set_xlabel('total bill')
ax1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
boxplot=plt.figure()
ax1=boxplot.add_subplot(1,1,1)
ax1.boxplot([tips[tips['sex']=='Female']['tip'],
            tips[tips['sex']=='Male']['tip']],
            labels=['Female','Male']
           )
ax1.set_title('boxplot of tips by sex')
ax1.set_xlabel('sex')
ax1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
def recode_sex(sex):
    if sex=='Female':
        return 0
    else:
        return 1

tips['sex_color']=tips['sex'].apply(recode_sex)

scatters=plt.figure()
ax1=scatters.add_subplot(1,1,1)
ax1.scatter(tips['total_bill'],tips['tip'],
            s=tips['size']*10,c=tips['sex_color'],alpha=0.5)
ax1.set_title('total bill vs tip colored by sex and sized by size')
ax1.set_xlabel('total bill')
ax1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %% [markdown]
# ---
# 3. seaborn library - tips dataset

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'])
ax.set_title('total bill histogram with density plot')

ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],kde=False)
ax.set_title('total bill histogram')

ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],hist=False)
ax.set_title('total bill density')

ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],rug=True)
ax.set_title('total bill histogram with density and rug plot')

ax=plt.subplots()
ax=sns.countplot('day',data=tips)
ax.set_title('count of days')
# Out:
# Text(0.5, 1.0, 'count of days')

# %%
#산점도 그래프
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips)
ax.set_title('scatterplot of total bill and tip')

ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('scatterplot of total bill and tip')
# Out:
# Text(0.5, 1.0, 'scatterplot of total bill and tip')

# %%
#jointplot
ax=sns.jointplot(x='total_bill',y='tip',data=tips)
ax.fig.suptitle('joint plot of total bill and tip',y=1.03)
# Out:
# Text(0.5, 1.03, 'joint plot of total bill and tip')

# %%
#jointplot hexbin
ax=sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
ax.fig.suptitle('joint plot of total bill and tip',y=1.03)
# Out:
# Text(0.5, 1.03, 'joint plot of total bill and tip')

# %%
#이차원 밀집도 kdeplot
ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'],shade=True)
ax.set_title('kernel density plot of total bill and tip')
# Out:
# Text(0.5, 1.0, 'kernel density plot of total bill and tip')

# %%
#bar graph barplot
ax=plt.subplots()
ax=sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title('bar plot of average total bill for time of day')
# Out:
# Text(0.5, 1.0, 'bar plot of average total bill for time of day')

# %%
#box graph boxplot
ax=plt.subplots()
ax=sns.boxplot(x='time',y='total_bill',data=tips)
ax.set_title('boxplot of total bill by time of day')

#violinplot
ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('violin plot of total bill by time of day')

ax=plt.subplots()
ax=sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
ax.set_title('violin plot of total bill by time of day')
# Out:
# Text(0.5, 1.0, 'violin plot of total bill by time of day')

# %%
#pairplot
ax=sns.pairplot(tips)

# %%
#pairplot hue=sex
ax=sns.pairplot(tips,hue='sex')

# %%
#pairgrid
pair=sns.PairGrid(tips)
pair=pair.map_upper(sns.regplot)
pair=pair.map_lower(sns.kdeplot)
pair=pair.map_diag(sns.distplot,rug=True)
plt.show()

# %%
#lmplot
ax=sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',fit_reg=False)

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
ax=sns.lmplot(x='x',y='y',data=anscombe,fit_reg=False,
             col='dataset',col_wrap=2)

# %% [markdown]
# ---
# 4. DF, Series visualization

# %%
# series graph
ax=plt.subplots()
ax=tips['total_bill'].plot.hist()

ax=tips[['total_bill','tip']].plot.hist(alpha=0.5,bins=20)

# %% [markdown]
# ---
# 5. seaborn library graph style

# %%
ax=plt.subplots()
ax=tips['tip'].plot.kde()

ax=tips.plot.scatter(x='total_bill',y='tip')

ax=tips.plot.hexbin(x='total_bill',y='tip')

ax=tips.plot.hexbin(x='total_bill',y='tip',gridsize=20)

ax=tips.plot.box()

# %%
fig=plt.figure()
styles=['darkgrid','whitegrid','dark','white','ticks']
for idx,style in enumerate(styles):
    plot_position=idx+1
    with sns.axes_style(style):
        ax=fig.add_subplot(2,3,plot_position)
        vi=sns.violinplot(x='time',y='total_bill',data=tips,split=True)
        vi.set_title(style)
    fig.tight_layout()
